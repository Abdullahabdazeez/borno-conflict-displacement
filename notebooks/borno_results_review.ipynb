# %% [markdown]
# # Borno Conflict, Displacement and Settlement Change — Results Review
# This notebook loads the final settlement and LGA evidence tables published in the repository.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
settlements = pd.read_csv(ROOT / 'data/processed/tables/Publication_Table_01_Final_Settlement_Results.csv')
settlements

# %%
decisions = pd.read_csv(ROOT / 'data/processed/tables/Publication_Table_02_Decision_Distribution.csv')
decisions

# %%
lga = pd.read_csv(ROOT / 'data/processed/tables/Publication_Table_03_LGA_Result_Summary.csv')
lga
